# %%
import importlib
import generate
# reload if generate.py has changed
importlib.reload(generate)

generate.clear_logs()

results = await generate.generate_with_standard_settings()
# Out:
# /opt/venvs/SoCloverAI/lib/python3.12/site-packages/langchain_classic/embeddings/cache.py:58: UserWarning: Using default key encoder: SHA-1 is *not* collision-resistant. While acceptable for most cache scenarios, a motivated attacker can craft two different payloads that map to the same cache key. If that risk matters in your environment, supply a stronger encoder (e.g. SHA-256 or BLAKE2) via the `key_encoder` argument. If you change the key encoder, consider also creating a new cache, to avoid (the potential for) collisions with existing keys.
#   _warn_about_sha1_encoder()
# Generating m10_brainstorm_candidates_line
#   Temperature 0.0
#     Trial 1 of 3
# /workspaces/SoCloverAI/GenerateClues/simple_llm_cache.py:63: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   generations.append(loads(generation))
# ...

# %%
import evaluate
# reload if evaluate.py has changed
importlib.reload(evaluate)

evaluate.evaluate(results)
# Out:
# Method, Temperature, 10%, 50%, 90%
# m10_brainstorm_candidates_line, 0.0, 1.00, 2.00, 3.00
# m10_brainstorm_candidates_line, 0.5, 1.00, 2.00, 3.00
# m10_brainstorm_candidates_line, 0.9, 1.00, 2.00, 3.00
# m09_embeddings, 0.0, 0.00, 1.00, 2.00
# m09_embeddings, 0.5, 0.00, 1.00, 2.00
# m09_embeddings, 0.9, 0.00, 1.00, 2.00
# m08_brainstorm_candidates, 0.0, 1.00, 2.00, 3.00
# m08_brainstorm_candidates, 0.5, 1.00, 2.00, 3.00
# m08_brainstorm_candidates, 0.9, 1.00, 2.00, 3.00
# m07_brainstorm_expert_criteria_examples, 0.0, 1.00, 2.00, 4.00
# m07_brainstorm_expert_criteria_examples, 0.5, 1.00, 2.00, 4.00
# m07_brainstorm_expert_criteria_examples, 0.9, 1.00, 2.00, 4.00
# m06_brainstorm, 0.0, 1.00, 3.00, 4.00
# m06_brainstorm, 0.5, 1.00, 3.00, 4.00
# m06_brainstorm, 0.9, 1.00, 3.00, 4.00
# m05_expert_criteria_examples, 0.0, 1.00, 2.00, 3.00
# m05_expert_criteria_examples, 0.5, 1.00, 2.00, 3.00
# m05_expert_criteria_examples, 0.9, 1.00, 2.00, 3.00
# m04_examples, 0.0, -1.00, 1.00, 4.00
# ...

# %%
import importlib
import play
import generate

# reload if certain source files have changed
importlib.reload(play)
importlib.reload(generate)
# Out:
# <module 'generate' from '/workspaces/SoCloverAI/GenerateClues/generate.py'>

# %%
await play.play(
    [
        ("hot", "heart"),
        ("gas", "short"),
        ("drink", "stud"),
        ("camera", "cross"),
    ]
)
# Out:
# Generating: Trial 1 of 1
# Waiting for 36 tasks
#         Find near: hot & heart
#           Hat, stagehands, hem, hood, lover, hr, hip, haven, hand, Healthy, Hop, hrs, heat, Hand, healthy, hole, health, Shock, hoot, hands
#         Find near: hot heart
#           hearted, heartthrob, hearts, sweetheart, Hearts, overheat, hotter, Sweetheart, heartwarming, sweethearts, hot, heartbeat, hotshot, overheated, Heat, heatwave, Heart, heart, heartbreaker, heat
#         Find near: heart hot
#           HOT, hot, hotter, Hot, Heat, hotshot, hotly, heat, scorching, heartthrob, hottest, warm, overheat, hearted, HEAT, heatwave, Hottest, heated, overheated, steamy
#         hot heart -> Heat, heat, scorching, overheat, warm, HEAT, heatwave, heated, overheated, steamy, Hat, stagehands, hem, hood, lover, hr, hip, haven, hand, Healthy, Hop, hrs, Hand, healthy, hole, health, Shock, hoot, hands
#         Find near: gas & short
# ...

# %%
await play.play([
    ("brush", "town"),
    ("sky", "grave"),
    ("train", "beast"),
    ("volcano", "fishing"),
])
# Out:
# Generating: Trial 1 of 1
# Waiting for 36 tasks
#         Find near: brush & town
#           toolbox, bury, bout, tube, brook, biz, haven, creator, coop, toolbar, tailgate, nap, axed, Guild, toy, bomb, hub, soup, Tool, grown
#         Find near: brush town
#           Brush, brush, brushes, brushed, boroughs, borough, bushes, Towne, bury, brown, bushfire, Towns, brook, brushing, township, brick, toothbrush, Brixton, bristles, paint
#         Find near: town brush
#           Brush, brushes, bushes, brushed, brush, toothbrush, bristles, brushing, toothbrushes, bristling, bristle, shrubs, woods, Bushes, broom, bush, grass, woodland, switchgrass, bristled
#         brush town -> bushes, bristles, toolbox, bristling, bristle, shrubs, woods, Bushes, bury, broom, boroughs, bush, grass, bout, tube, brook, borough, biz, woodland, haven, creator, coop, switchgrass, bristled, toolbar, tailgate, nap, axed, Guild, toy, bomb, hub, soup, Tool, grown, brown, bushfire, brick, Brixton, paint
# ...

# %%
await play.play(
    [
        ("virus", "triangle"),
        ("weather", "reptile"),
        ("major", "revolution"),
        ("fry", "paper"),
    ]
)
# Out:
# Generating: Trial 1 of 1
# Waiting for 36 tasks
#         Find near: virus & triangle
#           clone, killer, particle, vice, axed, cult, opus, mime, victim, drug, bomb, machine, slug, breaker, protein, dummy, seduced, ounce, via, anger
#         Find near: virus triangle
#           viruses, virus, Virus, triumvirate, triangular, triangles, Triad, trilateral, trifecta, trio, Triangle, viral, triple, antivirus, triples, norovirus, troika, triangle, malware, trilogy
#         Find near: triangle virus
#           Triangle, triangle, triumvirate, triangular, trilateral, triangles, triple, triples, trifecta, Triple, tricycle, viruses, Triad, triplets, trio, troika, Tri, tri, triathlon, tripling
# ...

# %%
await play.play(
    [
        ("gamble", "stick"),
        ("country", "river"),
        ("radio", "chain"),
        ("cold", "port"),
    ]
)
# Out:
# Generating: Trial 1 of 1
# Waiting for 36 tasks
#         Find near: gamble & stick
#           ballgame, lay, stakes, slot, dice, tempt, spin, jug, Dice, ply, risk, fight, bling, engage, seduce, Chance, slip, spent, seduced, tries
#         Find near: gamble stick
#           gamble, Sticks, Gamble, gambles, stick, gambler, gambled, gamblers, gambling, Stick, sticks, joystick, chopsticks, sticking, yardstick, Gamblers, wagers, roulette, gambit, wager
#         Find near: stick gamble
#           gamble, Gamble, gambles, gambled, gambling, wagers, gambler, wager, gamblers, stakes, roulette, Gamblers, betting, Gambling, bets, wagering, Bets, Betting, wagered, dice
#         gamble stick -> wagers, wager, stakes, roulette, betting, bets, wagering, Bets, Betting, wagered, dice, ballgame, lay, slot, gambit, tempt, spin, jug, Dice, ply, risk, fight, bling, engage, seduce, Chance, slip, spent, seduced, tries
#         Find near: country & river
# ...
